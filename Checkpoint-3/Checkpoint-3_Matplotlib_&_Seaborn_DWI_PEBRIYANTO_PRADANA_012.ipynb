# %% [markdown]
# # **BUSINESS UNDERSTANDING**

# %% [markdown]
# ## **Bussiness Objective**

# %% [markdown]
# Tujuan utama proyek ini adalah menganalisis harga rumah berdasarkan faktor-faktor tertentu. faktor-faktor tersebut meliputi luas area, banyak kamar tidur, banyak kamar mandi, tingkat, letaknya dengan jalan raya, ruang tamu, basement dan fasilitas yang ada. analisis ini untuk membantu pembeli dalam memilih rumah dengan harga yang wajar dan membantu seorang penjual rumah dalam menentukan harga rumah yang akan dijual.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Situasi bisnis yang mendasari analisis ini untuk membantu pembeli rumah dalam menentukan apakah harga yang ditawarkan penjual kepadanya sesuai dengan harga pasar, dan memberikan data nyata untuk menambah keyakinan dalam memberi rumah. sedangkan bagi penjual, prediksi harga membantu menetapkan harga yang kompetitif berdasarkan tren pasar dan dapat meminimalisir kerugian dalam menjual rumah. Dengan adanya prediksi harga yang akurat, pasar properti menjadi lebih transparan dan efisien, mengurangi spekulasi berlebihan, serta menciptakan harga yang lebih adil.

# %% [markdown]
# ## **Data Mining Goals**
# Menganalisis dan memprediksi harga rumah berdasarkan fitur yang tersedia dalam dataset, memahami faktor utama yang berpengaruh terhadap harga rumah, Menyediakan wawasan bagi pengguna untuk pengambilan keputusan membeli atau menjual rumah dengan fasilitas-fasilitas yang ada.

# %% [markdown]
# ## **Project Plan**
# 1. mengumpulkan dan menyiapkan data.
# 2. membersihkan data.
# 3. menganalisis korelasi antara fitur dengan harga rumah.
# 4. mencari faktor yang sangat berpengaruh terhadap harga rumah.
# 5. Menyajikan hasil dalam bentuk dashboard atau laporan analitik.

# %% [markdown]
# # **CHECPOINT 2**

# %% [markdown]
# # **DATA UNDERTANDING**
# Sumber data : https://www.kaggle.com/datasets/yasserh/housing-prices-dataset

# %%
import pandas as pd

# %% [markdown]
# ### **Membaca Data**

# %%
file_path = "/content/drive/MyDrive/File_Praktikum_AVD/Housing.csv"

df = pd.read_csv(file_path)

# %% [markdown]
# ## **Pengecekan Struktur Data**

# %% [markdown]
# ### **menampilkan 5 baris pertama**

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ### **Menampilkan 5 baris akhir data**

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %% [markdown]
# ### **Menampilkan ringkasan dataset, yaitu jumlah baris, kolom, dan tipe data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ### **menampilkan jumlah baris dan kolom dalam dataset dengan format (baris, kolom)**

# %%
df.shape
# Out:
# (545, 13)

# %% [markdown]
# ### **Menampilkan tipe data dari setiap kolom**

# %%
df.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %% [markdown]
# # **Statistik deskriptif**

# %% [markdown]
# ### **Menampilkan statistik ringkasan seperti mean, median, min, max, dan kuartil**

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %% [markdown]
# ### **Menghitung jumlah kemunculan nilai unik dalam kolom tertentu**

# %%
df.value_counts()
# Out:
# price     area   bedrooms  bathrooms  stories  mainroad  guestroom  basement  hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# 1750000   2910   3         1          1        no        no         no        no               no               0        no        furnished           1
# 5229000   7085   3         1          1        yes       yes        yes       no               no               2        yes       semi-furnished      1
# 5110000   11410  2         1          2        yes       no         no        no               no               0        yes       furnished           1
# 5145000   3410   3         1          2        no        no         no        no               yes              0        no        semi-furnished      1
#           7980   3         1          1        yes       no         no        no               no               1        yes       semi-furnished      1
# ...

# %% [markdown]
# ### **Menghitung rata-rata**

# %%
df.mean(numeric_only=True)
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %% [markdown]
# menggunakan numeric_only=true dikarenakan terdapat data yang bukan angka.

# %% [markdown]
# ### **Menghitung median**

# %%
df.median(numeric_only=True)
# Out:
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %% [markdown]
# menggunakan numeric_only=true dikarenakan terdapat data yang bukan angka.

# %% [markdown]
# ### **Menghitung standar deviasi**

# %%
df.std(numeric_only=True)
# Out:
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %% [markdown]
# menggunakan numeric_only=true dikarenakan terdapat data yang bukan angka.

# %% [markdown]
# ### **Menghitung korelasi antar kolom numerik**

# %%
df.corr(numeric_only=True)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %% [markdown]
# area memiliki korelasi tertinggi dengan harga rumah, artinya area sangat berpengaruh terhadap harga rumah. bathrooms dan stories juga berdampak besar terhadap harga rumah.bedrooms dan parking memiliki korelasi yang lemah, tetapi masih relevan dengan harga rumah. korelasi parking terhadap harga mungkin memiliki pengaruh lebih rendah dalam menentukan harga rumah.

# %% [markdown]
# # **DATA PREPARATION**
# Sumber data : https://www.kaggle.com/datasets/yasserh/housing-prices-dataset

# %% [markdown]
# ### **Memeriksa Missing Value**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# price               0.0
# area                0.0
# bedrooms            0.0
# bathrooms           0.0
# stories             0.0
# mainroad            0.0
# guestroom           0.0
# basement            0.0
# hotwaterheating     0.0
# airconditioning     0.0
# parking             0.0
# prefarea            0.0
# furnishingstatus    0.0
# dtype: float64

# %% [markdown]
# Tidak ada mising value pada dataset ini

# %% [markdown]
# ### **Memeriksa Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %% [markdown]
# tidak ditemukan nilai duplikat pada dataset ini

# %% [markdown]
# ### **Memeriksa Outlier**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# price                 2.752294
# area                  2.201835
# bedrooms              2.201835
# bathrooms             0.183486
# stories               7.522936
# parking               2.201835

# %% [markdown]
# Tidak ada outlier yang melebihi 10%, maka outlier saya abaikan.

# %% [markdown]
# ## **Memeriksa Incosisten Value**

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# setelah di cek tidak ada incosisten value pada data set ini

# %% [markdown]
# ### **Melakukan Construct Data**

# %%
df["price_per_squere_foot"] = df["price"] / df["area"]
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# saya menambahkan kolom price per squere foot guna membandingkan harga antar rumah berdasarkan harga per luas kaki persegi juga.

# %% [markdown]
# ### **Melakukan Data Reduction**

# %% [markdown]
# agar mempermudah saya dalam menentukan data yang ingin di hapus saya ingin melihat korelasi data mainroad,	guestroom,	basement, hotwaterheating, airconditioning, dan	prefarea terhadap price yaitu dengan mengubah data tersebut menjadi numerik.

# %%
df['mainroad'] = df['mainroad'].map({'yes': 1, 'no': 0})
df['guestroom'] = df['guestroom'].map({'yes': 1, 'no': 0})
df['basement'] = df['basement'].map({'yes': 1, 'no': 0})
df['hotwaterheating'] = df['hotwaterheating'].map({'yes': 1, 'no': 0})
df['airconditioning'] = df['airconditioning'].map({'yes': 1, 'no': 0})
df['prefarea'] = df['prefarea'].map({'yes': 1, 'no': 0})
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                           price      area  bedrooms  bathrooms   stories  \
# price                  1.000000  0.535997  0.366494   0.517545  0.420712
# area                   0.535997  1.000000  0.151858   0.193820  0.083996
# bedrooms               0.366494  0.151858  1.000000   0.373930  0.408564
# bathrooms              0.517545  0.193820  0.373930   1.000000  0.326165
# stories                0.420712  0.083996  0.408564   0.326165  1.000000
# mainroad               0.296898  0.288874 -0.012033   0.042398  0.121706
# guestroom              0.255517  0.140297  0.080549   0.126469  0.043538
# basement               0.187057  0.047417  0.097312   0.102106 -0.172394
# hotwaterheating        0.093073 -0.009229  0.046049   0.067159  0.018847
# airconditioning        0.452954  0.222393  0.160603   0.186915  0.293602
# parking                0.384394  0.352980  0.139270   0.177496  0.045547
# prefarea               0.329777  0.234779  0.079023   0.063472  0.044425
# ...

# %% [markdown]
# dari korelasi di atas saya memutuskan untuk menghapus data mainroad, guestroom,	basement,	hotwaterheating, dan	prefarea.

# %%
df = df.drop('mainroad', axis=1)
df = df.drop('guestroom', axis=1)
df = df.drop('basement', axis=1)
df = df.drop('hotwaterheating', axis=1)
df = df.drop('prefarea', axis=1)
df
# Out:
#         price  area  bedrooms  bathrooms  stories  airconditioning  parking  \
# 0    13300000  7420         4          2        3                1        2
# 1    12250000  8960         4          4        4                1        3
# 2    12250000  9960         3          2        2                0        2
# 3    12215000  7500         4          2        2                1        3
# 4    11410000  7420         4          1        2                1        2
# ..        ...   ...       ...        ...      ...              ...      ...
# 540   1820000  3000         2          1        1                0        2
# 541   1767150  2400         3          1        1                0        0
# 542   1750000  3620         2          1        1                0        0
# 543   1750000  2910         3          1        1                0        0
# 544   1750000  3850         3          1        2                0        0
#
#     furnishingstatus  price_per_squere_foot
# ...

# %% [markdown]
# # **CHECKPOINT 3**

# %% [markdown]
# **Memanggil Library Matlotlib dan Seaborn**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### **COMPARATION**

# %%
plt.figure(figsize=(8, 5))
plt.bar(df['stories'].value_counts().index, df['stories'].value_counts().values, color=['lightcoral'])
plt.title('Jumlah Rumah per Banyak Tingkat')
plt.xlabel('Banyak Tingkat')
plt.ylabel('Jumlah Rumah')
plt.xticks(rotation=0)
plt.show()
print(df['stories'].value_counts())
# Out:
# stories
# 2    238
# 1    227
# 4     41
# 3     39
# Name: count, dtype: int64

# %% [markdown]
# Bar Chart ini menunjukkan jumlah rumah berdasarkan tingkatnya. Dari hasil visualisasi, terlihat bahwa rumah dengan tingkat 1 dan 2 memiliki jumlah lebih banyak dibandingkan dengan tingkat 3 dan 4. Hal ini dapat mengindikasikan bahwa lebih banyak rumah yang dibuat dengan tingkat yang rendah saja.
#
# rumah dengan tingkat lantai 3 dan 4 memiliki jumlah yang lebih rendah. Ini mungkin disebabkan oleh kurangnya peminat rumah yang terlalu tinggi, keterbatasan lahan atau biaya pembangunan yang tidak murah.

# %% [markdown]
# ### **DISTRIBUTION**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['price'], bins=10, kde=True, color='gold')
plt.title('Distribusi Harga Rumah')
plt.xlabel('Harga Rumah')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Histogram ini menunjukkan distribusi Harga Rumah, dengan sumbu x mewakili harga rumah dan sumbu y menunjukkan frekuensi kemunculan harga rumah tersebut. Grafik ini menggunakan 10 bins untuk mengelompokkan data dan dilengkapi dengan garis Kernel Density Estimate (KDE) yang menggambarkan pola distribusi secara lebih halus. Dari grafik, terlihat bahwa sebagian besar harga rumah berada di 3-5 jutaan, menunjukkan bahwa rumah dengan harga segitu lebih banyak atau lebih umum ditemukan di penjualan rumah.
#
# dari visualisasi tersebut seorang developer rumah atau penjual rumah bisa lebih Fokus pada pengembangan rumah di kisaran harga 3-5 juta karena ini adalah yang paling diminati. namun Jika ingin masuk ke pasar properti premium yaitu yang di atas 10 juta, lakukan riset tambahan apakah ada permintaan di segmen tersebut.
# untuk  Pembeli rumah, jika ingin investasi jangka panjang, rumah dengan harga 3-5 juta lebih mudah dijual kembali atau disewakan.

# %% [markdown]
# ### **COMPOSITION**

# %%
plt.figure(figsize=(6, 6))
plt.pie(df['furnishingstatus'].value_counts(), labels=df['furnishingstatus'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightgreen', 'gold'])
plt.title('Status Furnitur')
plt.show()

# %% [markdown]
# dari pie chart, rumah yang memiliki status semi-furnished lebih banyak Ini menunjukkan bahwa banyak penjual rumah memilih untuk menyediakan rumah dengan  sebagian perabotan untuk menarik pembeli yang menginginkan fleksibilitas dalam mendekorasi rumahnya. Rumah unfurnished juga lumayan banyak kemungkinan untuk
# Sebagian pembeli atau penyewa mungkin lebih suka rumah kosong agar bisa mengisi sendiri sesuai preferensi mereka. Rumah yang sudah lengkap dengan furnitur lebih jarang ditemukan. mungkin karena faktor harga, karena rumah fully furnished biasanya lebih mahal.
#
# tindakan yang dapat di ambil bagi penjual rumah, jika ingin menjual lebih cepat, bisa mempertimbangkan menawarkan paket semi-furnished.

# %% [markdown]
# ### **RELATIONSHIP**

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Antar Variabel')
plt.show()

# %% [markdown]
# Berdasarkan heatmap korelasi Luas Area memiliki korelasi positif dengan harga rumah  semakin besar luas rumah, semakin tinggi harganya. Namun, ada faktor lain yang memengaruhi harga rumah selain luas area. contohnya Rumah dengan  banyak kamar mandi dapat mempengaruhi tunggi nya harga rumah, mungkin karena memberikan kenyamanan lebih bagi penghuni. kemudian jumlah lantai , AC dan tempat parkir, yang juga beroengaruh terhadap harga rumah.
# Korelasi negatif antara price per square foot dengan luas area Artinya, semakin besar rumah, semakin rendah harga per meter perseginya.
#
# dari heatmap tersebut seorang devleloper atau penjual rumah rumah dapat melakukan peningkatkan jumlah kamar mandi karena faktor ini memiliki korelasi yang cukup kuat dengan harga. kemudian Menawarkan opsi AC dan lebih banyak tempat parkir dapat meningkatkan daya tarik properti. dan bagi seorang pembeli rumah Membeli rumah dengan luas besar mungkin lebih menguntungkan dalam jangka panjang, karena harga per meter perseginya lebih rendah.lalu Fokus pada rumah dengan lebih banyak kamar mandi karena lebih cenderung memiliki nilai jual yang lebih tinggi.

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['price'], df['area'], c='blue', alpha=0.5)
plt.title('Harga Rumah vs Luas Rumah')
plt.xlabel('Harga Rumah')
plt.ylabel('Luas Rumah')
plt.show()

# %% [markdown]
# Harga dan Luas Rumah memiliki hubungan positif Secara umum, semakin besar luas rumah, semakin tinggi harganya. Namun, hubungan ini tidak sepenuhnya linear karena ada beberapa rumah dengan harga tinggi tetapi luasnya tidak terlalu besar ada juga rumah yang luas namun harganya juga rendah, haltersebut di pengaruhi oleh faktor lain seperti fasilitas yang ada
#
# tindakan yang dapat di ambil bagi Pengembang penjual rumah, Pastikan harga rumah sesuai dengan luasnya dan ditambah faktor lain seperti lokasi dan fasilitas. Jika ingin menjual rumah premium, tawarkan fitur tambahan untuk membenarkan harga tinggi pada luas yang sama.
